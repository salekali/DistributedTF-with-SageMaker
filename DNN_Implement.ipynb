# %% [markdown]
# ## Set up the environment

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()

# %% [markdown]
# ## Upload the data to an S3 bucket

# %%
inputs = sagemaker_session.upload_data(path='data', key_prefix='data/DEMO-adult')

# %% [markdown]
# ## Create a training job

# %%
from sagemaker.tensorflow import TensorFlow

estimator = TensorFlow(entry_point='DNN_Classifier.py',
                             role=role,
                             training_steps=100, 
                             evaluation_steps=100,
                             train_instance_count=2,
                             train_instance_type='ml.c4.xlarge')

estimator.fit(inputs)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:sagemaker:Creating training-job with name: sagemaker-tensorflow-2018-05-22-00-31-59-361
# ..................
# 2018-05-22 00:34:45,219 INFO - root - running container entrypoint
# 2018-05-22 00:34:45,219 INFO - root - starting train task
# 2018-05-22 00:34:45,224 INFO - container_support.training - Training starting
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2018-05-22 00:34:46,935 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTP connection (1): 169.254.170.2
# 2018-05-22 00:34:47,146 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.amazonaws.com
# 2018-05-22 00:34:47,203 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-296813278751.s3.amazonaws.com
# 2018-05-22 00:34:47,220 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:47,276 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-296813278751.s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:47,422 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:47,456 INFO - tf_container - ----------------------TF_CONFIG--------------------------
# 2018-05-22 00:34:47,457 INFO - tf_container - {"environment": "cloud", "cluster": {"worker": ["algo-2:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "master": ["algo-1:2222"]}, "task": {"index": 0, "type": "worker"}}
# 2018-05-22 00:34:47,457 INFO - tf_container - ---------------------------------------------------------
# 2018-05-22 00:34:47,457 INFO - tf_container - creating RunConfig:
# 2018-05-22 00:34:47,458 INFO - tf_container - {'save_checkpoints_secs': 300}
# 2018-05-22 00:34:47,458 INFO - tensorflow - TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {u'ps': [u'algo-1:2223', u'algo-2:2223'], u'worker': [u'algo-2:2222'], u'master': [u'algo-1:2222']}, u'task': {u'index': 0, u'type': u'worker'}}
# 2018-05-22 00:34:47,458 INFO - tf_container - invoking the user-provided estimator_fn
# 2018-05-22 00:34:47,459 INFO - tensorflow - Using config: {'_save_checkpoints_secs': 300, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': u'worker', '_global_id_in_cluster': 1, '_is_chief': False, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f507ffc0fd0>, '_model_dir': u's3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints', '_num_worker_replicas': 2, '_task_id': 0, '_log_step_count_steps': 100, '_master': u'grpc://algo-2:2222', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_service': None, '_save_summary_steps': 100, '_num_ps_replicas': 2}
# 2018-05-22 00:34:47,460 INFO - tensorflow - Start Tensorflow server.
# 2018-05-22 00:34:47.483835: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2018-05-22 00:34:47.483829: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2018-05-22 00:34:47.484096: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2018-05-22 00:34:47.484263: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> localhost:2222}
# 2018-05-22 00:34:47.484103: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> localhost:2223}
# 2018-05-22 00:34:47.484303: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2018-05-22 00:34:47.485633: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# 2018-05-22 00:34:47,485 INFO - tensorflow - Waiting 5 secs before starting training.
# 2018-05-22 00:34:47.485645: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2223
# 2018-05-22 00:34:46,372 INFO - root - running container entrypoint
# 2018-05-22 00:34:46,373 INFO - root - starting train task
# 2018-05-22 00:34:46,378 INFO - container_support.training - Training starting
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 2018-05-22 00:34:48,123 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTP connection (1): 169.254.170.2
# 2018-05-22 00:34:48,326 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.amazonaws.com
# 2018-05-22 00:34:48,363 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-296813278751.s3.amazonaws.com
# 2018-05-22 00:34:48,376 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:48,475 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (2): sagemaker-us-west-2-296813278751.s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:48,601 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): s3.us-west-2.amazonaws.com
# 2018-05-22 00:34:48,646 INFO - tf_container - ----------------------TF_CONFIG--------------------------
# 2018-05-22 00:34:48,646 INFO - tf_container - {"environment": "cloud", "cluster": {"worker": ["algo-2:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "master": ["algo-1:2222"]}, "task": {"index": 0, "type": "master"}}
# 2018-05-22 00:34:48,646 INFO - tf_container - ---------------------------------------------------------
# 2018-05-22 00:34:48,646 INFO - tf_container - creating RunConfig:
# 2018-05-22 00:34:48,646 INFO - tf_container - {'save_checkpoints_secs': 300}
# 2018-05-22 00:34:48,646 INFO - tensorflow - TF_CONFIG environment variable: {u'environment': u'cloud', u'cluster': {u'ps': [u'algo-1:2223', u'algo-2:2223'], u'worker': [u'algo-2:2222'], u'master': [u'algo-1:2222']}, u'task': {u'index': 0, u'type': u'master'}}
# 2018-05-22 00:34:48,647 INFO - tf_container - invoking the user-provided estimator_fn
# 2018-05-22 00:34:48,647 INFO - tensorflow - Using config: {'_save_checkpoints_secs': 300, '_session_config': None, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_task_type': u'master', '_global_id_in_cluster': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc62c15bfd0>, '_model_dir': u's3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints', '_num_worker_replicas': 2, '_task_id': 0, '_log_step_count_steps': 100, '_master': u'grpc://algo-1:2222', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_service': None, '_save_summary_steps': 100, '_num_ps_replicas': 2}
# 2018-05-22 00:34:48,648 INFO - tensorflow - Start Tensorflow server.
# 2018-05-22 00:34:48.671942: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job master -> {0 -> algo-1:2222}
# 2018-05-22 00:34:48.671942: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job master -> {0 -> localhost:2222}
# 2018-05-22 00:34:48.672219: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> localhost:2223, 1 -> algo-2:2223}
# 2018-05-22 00:34:48.672228: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job ps -> {0 -> algo-1:2223, 1 -> algo-2:2223}
# 2018-05-22 00:34:48.672232: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2018-05-22 00:34:48.672250: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job worker -> {0 -> algo-2:2222}
# 2018-05-22 00:34:48.673670: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# 2018-05-22 00:34:48.673943: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2223
# 2018-05-22 00:34:48.682782: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/config and using profilePrefix = 1
# 2018-05-22 00:34:48.682814: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/credentials and using profilePrefix = 0
# 2018-05-22 00:34:48.682830: I tensorflow/core/platform/s3/aws_logging.cc:54] Setting provider to read credentials from /root//.aws/credentials for credentials file and /root//.aws/config for the config file , for use with profile default
# 2018-05-22 00:34:48.682842: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating HttpClient with max connections2 and scheme http
# 2018-05-22 00:34:48.682866: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 2
# 2018-05-22 00:34:48.682888: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating TaskRole with default ECSCredentialsClient and refresh rate 900000
# 2018-05-22 00:34:48.683054: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/credentials for reading.
# 2018-05-22 00:34:48.683067: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-05-22 00:34:48.683080: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/config for reading.
# 2018-05-22 00:34:48.683088: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-05-22 00:34:48.683099: I tensorflow/core/platform/s3/aws_logging.cc:54] Credentials have expired or will expire, attempting to repull from ECS IAM Service.
# 2018-05-22 00:34:48.690834: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-05-22 00:34:48.690978: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:48.695629: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 25
# 2018-05-22 00:34:48.705809: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-05-22 00:34:48.705846: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:48.787233: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:48.787297: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:48.788160: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:50,644 INFO - tensorflow - Calling model_fn.
# 2018-05-22 00:34:50,858 INFO - tensorflow - Done calling model_fn.
# 2018-05-22 00:34:50,859 INFO - tensorflow - Create CheckpointSaverHook.
# 2018-05-22 00:34:50.859334: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:50.967901: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:50.967956: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:50.968134: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:50.977617: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:50.985248: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:50.985281: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:50.985449: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:50.995915: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.003163: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:51.003194: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:51.003352: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.012427: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.022252: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034511526949291011
# 2018-05-22 00:34:51.063426: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.071792: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.080270: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.086103: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.095883: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.114964: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.131177: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.137103: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51,239 INFO - tensorflow - Graph was finalized.
# 2018-05-22 00:34:51.239940: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.335141: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:51.335186: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:51.335353: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.402610: I tensorflow/core/distributed_runtime/master_session.cc:1024] Start master session 686677a6fe694ad9 with config: allow_soft_placement: true
# 2018-05-22 00:34:51,508 INFO - tensorflow - Running local_init_op.
# 2018-05-22 00:34:51,511 INFO - tensorflow - Done running local_init_op.
# 2018-05-22 00:34:51.627494: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.631709: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:51.631745: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:51.631883: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.771984: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.840173: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034511526949291771
# 2018-05-22 00:34:51.841029: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.852067: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:51.986210: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52,337 INFO - tensorflow - Saving checkpoints for 1 into s3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints/model.ckpt.
# 2018-05-22 00:34:52.398060: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.405918: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034521526949292397
# 2018-05-22 00:34:52.410711: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.439765: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034521526949292405
# 2018-05-22 00:34:52.440490: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.454218: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.482676: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.491022: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.537201: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034521526949292490
# 2018-05-22 00:34:52.537472: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.548494: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.591120: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.398374: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/config and using profilePrefix = 1
# 2018-05-22 00:34:52.398404: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing config loader against fileName /root//.aws/credentials and using profilePrefix = 0
# 2018-05-22 00:34:52.398417: I tensorflow/core/platform/s3/aws_logging.cc:54] Setting provider to read credentials from /root//.aws/credentials for credentials file and /root//.aws/config for the config file , for use with profile default
# 2018-05-22 00:34:52.398428: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating HttpClient with max connections2 and scheme http
# 2018-05-22 00:34:52.398443: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 2
# 2018-05-22 00:34:52.398455: I tensorflow/core/platform/s3/aws_logging.cc:54] Creating TaskRole with default ECSCredentialsClient and refresh rate 900000
# 2018-05-22 00:34:52.398486: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/credentials for reading.
# 2018-05-22 00:34:52.398500: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-05-22 00:34:52.398511: I tensorflow/core/platform/s3/aws_logging.cc:54] Unable to open config file /root//.aws/config for reading.
# 2018-05-22 00:34:52.398518: I tensorflow/core/platform/s3/aws_logging.cc:54] Failed to reload configuration.
# 2018-05-22 00:34:52.398528: I tensorflow/core/platform/s3/aws_logging.cc:54] Credentials have expired or will expire, attempting to repull from ECS IAM Service.
# 2018-05-22 00:34:52.398683: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-05-22 00:34:52.398706: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.401449: I tensorflow/core/platform/s3/aws_logging.cc:54] Initializing CurlHandleContainer with size 25
# 2018-05-22 00:34:52.403330: I tensorflow/core/platform/s3/aws_logging.cc:54] Pool grown by 2
# 2018-05-22 00:34:52.403349: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.488244: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.538235: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:52.538274: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:52.538899: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.870379: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034521526949292402
# 2018-05-22 00:34:52.875058: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.921667: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034521526949292870
# 2018-05-22 00:34:52.922629: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.934948: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:52.998471: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.033987: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.046760: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034531526949293033
# 2018-05-22 00:34:53.046988: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.087090: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.131429: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.141964: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.148705: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034531526949293141
# 2018-05-22 00:34:53.148952: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.154593: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.163479: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.172160: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.180850: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.188905: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.195748: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.203691: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.212172: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.219998: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.228173: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.237179: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.463874: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.477026: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034531526949293463
# 2018-05-22 00:34:53.477346: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.487337: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.577881: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.613620: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.620066: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:53.620097: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:53.620225: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.639700: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.690044: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034531526949293639
# 2018-05-22 00:34:53.690387: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.713129: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.320204: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.328354: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.340856: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.395008: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.403133: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.413730: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034531526949293402
# 2018-05-22 00:34:53.413944: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.421580: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.430617: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.442165: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.448938: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.737225: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.749601: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.755410: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.763635: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.768726: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.778401: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.786522: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.803481: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.808822: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.818054: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53.825506: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:53,951 INFO - tensorflow - Calling model_fn.
# 2018-05-22 00:34:54,332 INFO - tensorflow - Done calling model_fn.
# 2018-05-22 00:34:54,351 INFO - tensorflow - Starting evaluation at 2018-05-22-00:34:54
# 2018-05-22 00:34:54,419 INFO - tensorflow - Graph was finalized.
# 2018-05-22 00:34:54,419 INFO - tensorflow - Restoring parameters from s3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints/model.ckpt-1
# 2018-05-22 00:34:54.464020: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.477442: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.482723: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.491800: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.498540: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.508983: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.517442: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.525645: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.532811: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.539717: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.548967: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54.555817: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:54,577 INFO - tensorflow - Running local_init_op.
# 2018-05-22 00:34:54,600 INFO - tensorflow - Done running local_init_op.
# 2018-05-22 00:34:54,367 INFO - tensorflow - Calling model_fn.
# 2018-05-22 00:34:54,586 INFO - tensorflow - Done calling model_fn.
# 2018-05-22 00:34:54,586 INFO - tensorflow - Create CheckpointSaverHook.
# 2018-05-22 00:34:54,663 INFO - tensorflow - Graph was finalized.
# 2018-05-22 00:34:54.681742: I tensorflow/core/distributed_runtime/master_session.cc:1024] Start master session 593dd5457daa68ec with config: allow_soft_placement: true
# 2018-05-22 00:34:54,724 INFO - tensorflow - Running local_init_op.
# 2018-05-22 00:34:54,727 INFO - tensorflow - Done running local_init_op.
# 2018-05-22 00:34:54,947 INFO - tensorflow - loss = 71.73244, step = 1
# 2018-05-22 00:34:55,039 INFO - tensorflow - Evaluation [10/100]
# 2018-05-22 00:34:55,123 INFO - tensorflow - Evaluation [20/100]
# 2018-05-22 00:34:55,189 INFO - tensorflow - Evaluation [30/100]
# 2018-05-22 00:34:55,264 INFO - tensorflow - Evaluation [40/100]
# 2018-05-22 00:34:55,348 INFO - tensorflow - Evaluation [50/100]
# 2018-05-22 00:34:55,416 INFO - tensorflow - Evaluation [60/100]
# 2018-05-22 00:34:55,498 INFO - tensorflow - Evaluation [70/100]
# 2018-05-22 00:34:55,563 INFO - tensorflow - Evaluation [80/100]
# 2018-05-22 00:34:55,627 INFO - tensorflow - Evaluation [90/100]
# 2018-05-22 00:34:55,688 INFO - tensorflow - Evaluation [100/100]
# 2018-05-22 00:34:55,898 INFO - tensorflow - Finished evaluation at 2018-05-22-00:34:55
# 2018-05-22 00:34:55,899 INFO - tensorflow - Saving dict for global step 1: accuracy = 0.7621094, accuracy_baseline = 0.7621094, auc = 0.5843883, auc_precision_recall = 0.31281787, average_loss = 0.5415321, global_step = 1, label/mean = 0.23789063, loss = 69.31611, prediction/mean = 0.22036551
# 2018-05-22 00:34:55.899349: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.905664: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:55.905698: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:55.905872: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.913353: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.918716: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:55.918804: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:55.919118: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.925827: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.932587: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:55.932620: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:55.932770: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.942166: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:55.949508: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034551526949295942
# 2018-05-22 00:34:56.006565: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.068895: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.077651: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.084438: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.093193: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.148879: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.202345: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.207827: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.367414: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.412437: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.478557: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.485108: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56,499 INFO - tensorflow - Calling model_fn.
# 2018-05-22 00:34:56,587 INFO - tensorflow - Done calling model_fn.
# 2018-05-22 00:34:56,587 INFO - tensorflow - Signatures INCLUDED in export for Classify: ['serving_default', 'classification']
# 2018-05-22 00:34:56,587 INFO - tensorflow - Signatures INCLUDED in export for Regress: ['regression']
# 2018-05-22 00:34:56,587 INFO - tensorflow - Signatures INCLUDED in export for Predict: ['predict']
# 2018-05-22 00:34:56.588332: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.594108: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.594140: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.594309: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56,616 INFO - tensorflow - Restoring parameters from s3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints/model.ckpt-1
# 2018-05-22 00:34:56.632753: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.646762: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.651959: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.660966: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.668578: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.678304: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.683863: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.692151: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.700458: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.707417: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.717126: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.724390: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.734495: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.740507: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.740540: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.741090: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57,307 INFO - tensorflow - Loss for final step: 36.739655.
# 2018-05-22 00:34:56.817178: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.822265: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.822294: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.822432: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.831908: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.836668: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.836706: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.836872: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.845950: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.851363: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.851396: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.851533: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.859891: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.866680: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:56.866708: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:56.866841: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.960716: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.973174: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034561526949296960
# 2018-05-22 00:34:56.973434: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.985530: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034561526949296973
# 2018-05-22 00:34:56.985780: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:56.995324: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034561526949296985
# 2018-05-22 00:34:56,995 INFO - tensorflow - Assets added to graph.
# 2018-05-22 00:34:56,995 INFO - tensorflow - No assets to write.
# 2018-05-22 00:34:56.995957: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.002893: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:57.002926: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:57.003098: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.014335: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.018294: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:57.018327: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:57.018475: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.028639: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.034521: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:57.034554: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:57.034698: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.048921: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.056600: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297048
# 2018-05-22 00:34:57.092518: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.099701: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297092
# 2018-05-22 00:34:57.103704: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.146480: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297099
# 2018-05-22 00:34:57.146718: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.158347: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.194253: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.202885: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.215060: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297202
# 2018-05-22 00:34:57.215257: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.226089: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.258862: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.268392: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.278025: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297268
# 2018-05-22 00:34:57.278300: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.284531: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.295226: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.304093: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.313265: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.321662: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.335503: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.367738: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.374443: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.403721: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0034571526949297374
# 2018-05-22 00:34:57.403935: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.412928: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.422626: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.451574: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:34:57.457462: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:34:57.457499: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:34:57.457661: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# ...
# 2018-05-22 00:34:58.380333: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:00,066 INFO - tensorflow - Evaluation [10/100]
# 2018-05-22 00:35:00,151 INFO - tensorflow - Evaluation [20/100]
# 2018-05-22 00:35:00,226 INFO - tensorflow - Evaluation [30/100]
# 2018-05-22 00:35:00,291 INFO - tensorflow - Evaluation [40/100]
# 2018-05-22 00:35:00,354 INFO - tensorflow - Evaluation [50/100]
# 2018-05-22 00:35:00,415 INFO - tensorflow - Evaluation [60/100]
# 2018-05-22 00:35:00,487 INFO - tensorflow - Evaluation [70/100]
# 2018-05-22 00:35:00,756 INFO - tensorflow - Evaluation [80/100]
# 2018-05-22 00:35:00,829 INFO - tensorflow - Evaluation [90/100]
# 2018-05-22 00:35:00,897 INFO - tensorflow - Evaluation [100/100]
# 2018-05-22 00:35:01,119 INFO - tensorflow - Finished evaluation at 2018-05-22-00:35:01
# 2018-05-22 00:35:01,119 INFO - tensorflow - Saving dict for global step 101: accuracy = 0.83304685, accuracy_baseline = 0.7619531, auc = 0.8805504, auc_precision_recall = 0.7028389, average_loss = 0.36105645, global_step = 101, label/mean = 0.23804687, loss = 46.215225, prediction/mean = 0.20987259
# 2018-05-22 00:35:01.120562: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.264432: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.347479: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.354179: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01,369 INFO - tensorflow - Calling model_fn.
# 2018-05-22 00:35:01,452 INFO - tensorflow - Done calling model_fn.
# 2018-05-22 00:35:01,452 INFO - tensorflow - Signatures INCLUDED in export for Classify: ['serving_default', 'classification']
# 2018-05-22 00:35:01,452 INFO - tensorflow - Signatures INCLUDED in export for Regress: ['regression']
# 2018-05-22 00:35:01,452 INFO - tensorflow - Signatures INCLUDED in export for Predict: ['predict']
# 2018-05-22 00:35:01.453157: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.459591: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.459619: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.459776: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01,483 INFO - tensorflow - Restoring parameters from s3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints/model.ckpt-101
# 2018-05-22 00:35:01.498124: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.512933: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.520294: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.526828: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.536025: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.544709: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.551450: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.560501: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.569710: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.577730: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.586750: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.594403: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.604945: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.609758: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.609787: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.609946: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.619442: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.626056: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.626085: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.626235: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.635199: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.639703: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.639735: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.639884: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.651606: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.659901: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301651
# 2018-05-22 00:35:01,660 INFO - tensorflow - Assets added to graph.
# 2018-05-22 00:35:01,660 INFO - tensorflow - No assets to write.
# 2018-05-22 00:35:01.660510: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.665098: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.665129: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.665269: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.674351: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.680112: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.680143: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.680288: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.686684: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.693450: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:01.693481: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:01.693629: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.709943: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.717235: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301709
# 2018-05-22 00:35:01.745811: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.752757: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301745
# 2018-05-22 00:35:01.756732: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.792452: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301752
# 2018-05-22 00:35:01.792691: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.803659: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.830663: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.839590: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.870015: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301839
# 2018-05-22 00:35:01.870232: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.882402: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.923921: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.933937: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.945911: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035011526949301933
# 2018-05-22 00:35:01.946117: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.953149: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.960677: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.968681: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.977247: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.985135: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:01.994595: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.019208: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.026135: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.064218: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035021526949302025
# 2018-05-22 00:35:02.064420: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.244897: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.257499: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.287512: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.292617: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:02.292645: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:02.292818: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.308851: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.341739: I tensorflow/core/platform/s3/aws_logging.cc:54] Deleting file: /tmp/s3_filesystem_XXXXXX20180522T0035021526949302308
# 2018-05-22 00:35:02,341 INFO - tensorflow - SavedModel written to: s3://sagemaker-us-west-2-296813278751/sagemaker-tensorflow-2018-05-22-00-31-59-361/checkpoints/export/Servo/temp-1526949301/saved_model.pb
# 2018-05-22 00:35:02.342203: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.349620: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:02.349647: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:02.349800: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.363364: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.377043: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.390856: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.399172: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.450111: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.457751: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.469549: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.476327: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.530270: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.539176: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.793125: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.806082: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.813547: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:02.813582: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:02.813726: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.825312: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.829574: E tensorflow/core/platform/s3/aws_logging.cc:60] No response body. Response code: 404
# 2018-05-22 00:35:02.829600: W tensorflow/core/platform/s3/aws_logging.cc:57] If the signature check failed. This could be because of a time skew. Attempting to adjust the signer.
# 2018-05-22 00:35:02.829751: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02.840334: I tensorflow/core/platform/s3/aws_logging.cc:54] Connection has been released. Continuing.
# 2018-05-22 00:35:02,854 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.amazonaws.com
# 2018-05-22 00:35:02,868 INFO - botocore.vendored.requests.packages.urllib3.connectionpool - Starting new HTTPS connection (1): sagemaker-us-west-2-296813278751.s3.us-west-2.amazonaws.com
# 2018-05-22 00:35:05,017 INFO - tf_container - Downloaded saved model at /opt/ml/model/export/Servo/1526949296/saved_model.pb
# ===== Job Complete =====
# Billable seconds: 203

# %% [markdown]
# The fit method will create a training job in two ml.c4.xlarge instances. The logs above will show the instances doing training, evaluation, and incrementing the number of training steps.
#
# In the end of the training, the training job will generate a saved model for TF serving.
